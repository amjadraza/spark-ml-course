# %% [markdown]
# <a href="https://colab.research.google.com/github/amjadraza/spark-ml-course/blob/main/Getting_Started_with_Google_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#
#
#    # **Getting Started with Google Colab**

# %% [markdown]
# Google Colaboratory is a free online cloud-based Jupyter notebook environment that allows us to train our machine learning and deep learning models on CPUs, GPUs, and TPUs.
#
# Here’s what I truly love about Colab. It does not matter which computer you have, what it’s configuration is, and how ancient it might be. You can still use Google Colab! All you need is a Google account and a web browser. And here’s the cherry on top – you get access to GPUs like Tesla K80 and even a TPU, for free!
#
# TPUs are much more expensive than a GPU, and you can use it for free on Colab. It’s worth repeating again and again – it’s an offering like no other.

# %% [markdown]
# You can go to Google Colab using [this link](https://https://colab.research.google.com/).
# This is the screen you’ll get when you open Colab:

# %% [markdown]
# ![GetImage.png](data:image/png;base64,...)

# %% [markdown]
# Click on the NEW NOTEBOOK button to create a new Colab notebook. You can also upload your local notebook to Colab by clicking the upload button:

# %% [markdown]
# ![GetImage (1).png](data:image/png;base64,...)

# %% [markdown]
# You can also import your notebook from Google Drive or GitHub, but they require an authentication process.

# %% [markdown]
# ![GetImage (2).png](data:image/png;base64,...)

# %% [markdown]
# You can rename your notebook by clicking on the notebook name and change it to anything you want. I usually name them according to the project I’m working on.

# %% [markdown]
# **Google Colab Runtimes – Choosing the GPU or TPU Option**

# %% [markdown]
# The ability to choose different types of runtimes is what makes Colab so popular and powerful. Here are the steps to change the runtime of your notebook:
#
# **Step 1**: Click ‘Runtime’ on the top menu and select ‘Change Runtime Type’:

# %% [markdown]
# ![GetImage (3).png](data:image/png;base64,...)

# %% [markdown]
# **Step 2**: Here you can change the runtime according to your need:

# %% [markdown]
# ![GetImage (4).png](data:image/png;base64,...)

# %% [markdown]
# A wise man once said, “With great power comes great responsibility.” I implore you to shut down your notebook after you have completed your work so that others can use these resources because various users share them. You can terminate your notebook like this:

# %% [markdown]
# ![GetImage (5).png](data:image/png;base64,...)

# %% [markdown]
# **Using Terminal Commands on Google Colab**

# %% [markdown]
# You can use the Colab cell for running terminal commands. Most of the popular libraries come installed by default on Google Colab. Yes, Python libraries like Pandas, NumPy, scikit-learn are all pre-installed.
#
# If you want to run a different Python library, you can always install it inside your Colab notebook like this:

# %%
# !pip install library_name

# %% [markdown]
# Pretty easy, right? Everything is similar to how it works in a regular terminal. We just you have to put an exclamation(!) before writing each command like:

# %%
# !ls
# Out:
# sample_data

# %% [markdown]
# or:

# %%
# !pwd
# Out:
# /content

# %% [markdown]
# **Cloning Repositories in Google Colab**

# %% [markdown]
# You can also clone a Git repo inside Google Colaboratory. Just go to your GitHub repository and copy the clone link of the repository:

# %% [markdown]
# ![GetImage (6).png](data:image/png;base64,...)

# %% [markdown]
# Then, simply run:

# %%
# !git clone https://github.com/analyticsvidhya/Complete-Guide-to-Parameter-Tuning-in-XGBoost-with-codes-in-Python.git
# Out:
# Cloning into 'Complete-Guide-to-Parameter-Tuning-in-XGBoost-with-codes-in-Python'...
# remote: Enumerating objects: 9, done.
# remote: Total 9 (delta 0), reused 0 (delta 0), pack-reused 9
# Unpacking objects: 100% (9/9), done.

# %% [markdown]
# ![GetImage (7).png](data:image/png;base64,...)

# %% [markdown]
# And there you go!

# %% [markdown]
# **Uploading Files and Datasets**

# %% [markdown]
# Here’s a must-know aspect for any data scientist. The ability to import your dataset into Colab is the first step in your data analysis journey.
#
# The most basic approach is to upload your dataset to Colab directly:

# %% [markdown]
# ![GetImage (8).png](data:image/png;base64,...)

# %% [markdown]
# You can use this approach if your dataset or file is very small because the upload speed in this method is quite low. Another approach that I recommend is to upload your dataset to Google Drive and mount your drive on Colab. You can do this in just one click of your mouse:

# %% [markdown]
# ![GetImage (9).png](data:image/png;base64,...)

# %% [markdown]
# You can also upload your dataset to any other platform and access it using its link. I tend to go with the second approach more often than not (when feasible).

# %% [markdown]
# **Saving Your Notebook**

# %% [markdown]
# All the notebooks on Colab are stored on your Google Drive. The best thing about Colab is that your notebook is automatically saved after a certain time period and you don’t lose your progress.
#
# If you want, you can export and save your notebook in both ***.py** and ***.ipynb** formats:

# %% [markdown]
# ![GetImage (10).png](data:image/png;base64,...)

# %% [markdown]
# Not just that, you can also save a copy of your notebook directly on GitHub, or you can create a GitHub Gist:

# %% [markdown]
# ![GetImage (11).png](data:image/png;base64,...)

# %% [markdown]
# **Exporting Data/Files from Google Colab**

# %% [markdown]
# You can export your files directly to Google Drive, or you can export it to the VM instance and download it by yourself:

# %% [markdown]
# ![GetImage (12).png](data:image/png;base64,...)

# %% [markdown]
# Exporting directly to the Drive is a better option when you have bigger files or more than one file. You’ll pick up these nuances as you work on bigger projects in Colab.

# %% [markdown]
# **Sharing Your Notebook**

# %% [markdown]
# Google Colab also gives us an easy way of sharing our work with others. This is one of the best things about Colab:

# %% [markdown]
# ![GetImage (13).png](data:image/png;base64,...)

# %% [markdown]
# Just click the Share button, and it gives us the option of creating a shareable link that we can share through any platform. You can also invite others using their email IDs. It’s exactly the same as sharing a Google Doc or Google Sheet. The intricacies and simplicity of Google’s ecosystem are astounding!

# %% [markdown]
# ![GetImage (14).png](data:image/png;base64,...)

# %% [markdown]
# ## **Using Google Colab with Visual Studio Code**

# %% [markdown]
# Google Colab and VS Code are the most popular editor tools used by many Python developers and Researchers to develop different tech solutions or systems (especially in Machine Learning & Data Science).

# %% [markdown]
# Many Python developers and Data scientists know how to use Google Colab, but do you know that you can set up a VS Code on Google Colab and use it as an editor the same way as in your local machine?

# %% [markdown]
# **Installing the colabcode python package**

# %% [markdown]
# The first step is to launch a new colab notebook in your Google Colab and you can rename the file as you want.
#
# For example,  run_vscode.ipynb

# %% [markdown]
# To use Google Colab with VS Code (code server), you need to install the colabcode python package
#
# To **install** the package, run the following command in your notebook cell.

# %%
# !pip install colabcode
# Out:
# ...
#      |████████████████████████████████| 745 kB 11.0 MB/s
# ...
#      |████████████████████████████████| 45 kB 2.9 MB/s
# ...
#      |████████████████████████████████| 8.3 MB 40.9 MB/s
# ...
#      |████████████████████████████████| 55 kB 3.6 MB/s
# ...
#      |████████████████████████████████| 392 kB 72.8 MB/s
# ...
#      |████████████████████████████████| 428 kB 70.8 MB/s
# ...
#      |████████████████████████████████| 54 kB 3.3 MB/s
# ...
#      |████████████████████████████████| 52 kB 1.5 MB/s
# ...
#      |████████████████████████████████| 122 kB 59.1 MB/s
# ...
#      |████████████████████████████████| 77 kB 6.4 MB/s
# ...
#      |████████████████████████████████| 122 kB 54.0 MB/s
# ...
#      |████████████████████████████████| 122 kB 72.5 MB/s
# ...
#      |████████████████████████████████| 112 kB 73.6 MB/s
# ...
#      |████████████████████████████████| 56 kB 3.7 MB/s
# ...
#   Created wheel for pyngrok: filename=pyngrok-5.1.0-py3-none-any.whl size=19006 sha256=ecbf8c758b5f832dca44219f147ea21b2712e0eeaed37aea85e745aeabc3216f
# ...

# %% [markdown]
# The next step is to **import** ColabCode class from the package.

# %%
from colabcode import ColabCode

# %% [markdown]
# After importing the ColabCode, you need to create an instance of ColabCode and set the following arguments.
#
# **Port** :The port you want to run code-server on. For example port=10000
#
# **Password** s:You can set a password to protect your code-server from unauthorized access. This is an optional argument.
#
# **Mount_drive**  - If you want to use your Google drive. This is a Boolean argument means you can set True or False. This is an optional argument.

# %%
ColabCode(port=10000)
# Out:
# Code Server can be accessed on: NgrokTunnel: "https://0e38-35-233-241-193.ngrok.io" -> "http://localhost:10000"
# [2021-09-06T16:57:33.426Z] info  code-server 3.10.2 387b12ef4ca404ffd39d84834e1f0776e9e3c005
# [2021-09-06T16:57:33.428Z] info  Using user-data-dir ~/.local/share/code-server
# [2021-09-06T16:57:33.450Z] info  Using config file ~/.config/code-server/config.yaml
# [2021-09-06T16:57:33.450Z] info  HTTP server listening on http://127.0.0.1:10000
# [2021-09-06T16:57:33.450Z] info    - Authentication is disabled
# [2021-09-06T16:57:33.450Z] info    - Not serving HTTPS

# %% [markdown]
# After running the ColabCode instance, it will start the server and show the link to access the code server.

# %% [markdown]
# ![zVaxL0LohRUpfDQhznRQ9z3y5tj1-dk363205.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# You need to click the link and it will open in a new tab.

# %% [markdown]
# ![zVaxL0LohRUpfDQhznRQ9z3y5tj1-ad3f32yn.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Now you can take advantage of a full-fledged code editor and run different experiments on the Colab VM.
#
# **Note**: If you check on your Colab Notebook, you will observe the cell that runs the ColabCode instance is continuously running. Don't close your Colab notebook unless you want to close the code server that runs VS Code.

# %% [markdown]
# After launching the code server, the following tips will help you start using VS Code on Google Colab.

# %% [markdown]
# **Open Terminal**

# %% [markdown]
# To open the terminal on VS Code that runs on Google Colab, use the following shortcut command  **Ctrl + Shift + `**

# %% [markdown]
# ![zVaxL0LohRUpfDQhznRQ9z3y5tj1-w93w3210.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Change Theme**

# %% [markdown]
# You can change the theme of the editor by clicking the setting icon (bottom-left corner) and then click "Color Theme". It will open a popup window with different theme options you can select.

# %% [markdown]
# ![zVaxL0LohRUpfDQhznRQ9z3y5tj1-gp4832sm.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Run Python File**

# %% [markdown]
# You can create a python file by clicking the "File" section on the sidebar and then select a "New File" tab.

# %% [markdown]
# ![zVaxL0LohRUpfDQhznRQ9z3y5tj1-rd4f32fb.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# In the following example, you will see how to run a simple python file that trains a machine-learning algorithm to classify iris flowers into three species (setosa, versicolor, or virginica) and then make a prediction.

# %% [markdown]
# ![zVaxL0LohRUpfDQhznRQ9z3y5tj1-9w4r327c.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# You can also use the colabcode python package on the Kaggle platform to run VS Code. You just need to follow the same steps mentioned above.

# %% [markdown]
# ###**Basic Linux Commands**

# %% [markdown]
# The following command shows the user his current working *directory*

# %%
# !pwd
# Out:
# /content

# %% [markdown]
#  The following command lists all the files in the current working directory.

# %%
! ls
# Out:
# sample_data

# %% [markdown]
# This commands gives the username of the current user.

# %%
! whoami
# Out:
# root

# %% [markdown]
# This command creates a new folder or directory.

# %%
! mkdir DIY

# %% [markdown]
# Let's check if DIY is created and is now in the list of folders in the current directory.

# %%
! ls
# Out:
# DIY  sample_data

# %% [markdown]
# The following command deletes a directory or folder.

# %%
! rmdir DIY

# %% [markdown]
# Let's check the files using ls to see if DIY was deleted.

# %%
! ls
# Out:
# sample_data

# %% [markdown]
#  This command leads to a change in directory

# %%
cd sample_data
# Out:
# /content/sample_data

# %% [markdown]
# To move back to the previous directory we use the following command

# %%
cd ..
# Out:
# /content

# %% [markdown]
# If we type *cd* only, we move to the home directory. In this case, it moves to /root

# %%
cd
# Out:
# /root

# %%
cd /content
# Out:
# /content

# %% [markdown]
# The touch command is used to create a file. It can be anything, from an empty txt file to an empty zip file.

# %%
! touch new.txt

# %%
! ls
# Out:
# new.txt  sample_data

# %% [markdown]
# To know more about a command and how to use it, use the man command. It shows the manual pages of the command.

# %%
#! man cd

# %% [markdown]
# Use the cp command to copy files through the command line. It takes two arguments: The first is the location of the file to be copied, the second is where to copy.

# %%
cp new.txt sample_data

# %% [markdown]
# You can check if the file copied exists in the directory you copied to.

# %%
ls sample_data
# Out:
# anscombe.json*                mnist_test.csv         README.md*
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  new.txt

# %% [markdown]
# Use the mv command to move files through the command line. We can also use the mv command to rename a file.

# %%
cd sample_data
# Out:
# /content/sample_data

# %%
mv new.txt newer.txt

# %% [markdown]
# You can verify it using *ls*

# %%
ls
# Out:
# anscombe.json*                mnist_test.csv         README.md*
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  newer.txt

# %% [markdown]
# The "echo" command helps us move some data, usually text into a file.

# %%
# !echo hello, i am user >> newer.txt

# %% [markdown]
# Use the cat command to display the contents of a file. It is usually used to easily view programs.

# %%
# !cat newer.txt
# Out:
# hello, i am user

# %% [markdown]
# Use the df command to see the available disk space in each of the partitions in your system.

# %%
! df
# Out:
# Filesystem     1K-blocks     Used Available Use% Mounted on
# overlay        112947452 38696304  74234764  35% /
# tmpfs              65536        0     65536   0% /dev
# tmpfs            6651464        0   6651464   0% /sys/fs/cgroup
# shm              6160384        0   6160384   0% /dev/shm
# tmpfs            6651464       36   6651428   1% /var/colab
# /dev/sda1       79368748 43027444  36324920  55% /etc/hosts
# tmpfs            6651464        0   6651464   0% /proc/acpi
# tmpfs            6651464        0   6651464   0% /proc/scsi
# tmpfs            6651464        0   6651464   0% /sys/firmware

# %% [markdown]
# A widely used command in the Linux command line, *sudo* stands for "SuperUser Do". So, if you want any command to be done with administrative or root privileges, you can use the *sudo* command.
# Use *apt* to work with packages in the Linux command line. Use *apt-get* to install packages. This requires root privileges, so use the *sudo* command with it.
